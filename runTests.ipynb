# %%
from src.environment import RandomGridWorld
from src.environment import ActionSpace
g = RandomGridWorld()
g.plot()

# %%
g.step(ActionSpace.idle)
g.plot()
print(g.cumulativeReturn)
print(g.agentPosition)
print(g.goalState)
# Out:
# 95
# (9, 11)
# (9, 11)
